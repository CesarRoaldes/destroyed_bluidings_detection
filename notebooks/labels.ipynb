# %% [markdown]
# # Notebook, mise en place des labels

# %%
import geopandas
import numpy as np
import pandas as pd
import geopandas as gpd
import geoplot
import geoplot.crs as gcrs
import matplotlib.pyplot as plt

# %%
import os 
os.chdir("..")
wd=os.getcwd()
wd
# Out:
# 'C:\\Users\\morga\\Documents\\GitHub\\satellite_imagery'

# %% [markdown]
# ### La ville de Ezzor

# %%
from zipfile import ZipFile
zip = ZipFile(wd+'\\data\\UNITAR_data\\CE20130604SYR_Raqqa_Deir_shp.zip')
zip.extractall('temp') # Enlever le fichier temp à la fin ca entre pas dans le git :// !!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
data_ezzor=gpd.read_file('temp\Damage_Sites_Deir_ez_Zor_CDA.shp')

# %% [markdown]
# On ne garde que les dernières observation qui datent de 2017.

# %%
data_ezzor=data_ezzor[['SiteID','SensDt5','SensId5','ConfId5','DaSitCl5','Damst5','GrDaCl','FieldVl','Neigh','Code','geometry']]

# %%
data_ezzor
# Out:
#                             SiteID     SensDt5      SensId5    ConfId5  \
# 0     Building (General / Default)  2017-11-09  Worldview-2     Medium
# 1     Building (General / Default)  2017-11-09  Worldview-2     Medium
# 2     Building (General / Default)  2017-11-09  Worldview-2  Uncertain
# 3     Building (General / Default)  2017-11-09  Worldview-2     Medium
# 4     Building (General / Default)  2017-11-09  Worldview-2  Very High
# ...                            ...         ...          ...        ...
# 7037                          Road  2017-11-09  Worldview-2  Very High
# 7038                          Road  2017-11-09  Worldview-2     Medium
# 7039                          Road  2017-11-09  Worldview-2  Very High
# 7040                          Road  2017-11-09  Worldview-2     Medium
# 7041                          Road  2017-11-09  Worldview-2     Medium
#
#                             DaSitCl5        Damst5  \
# 0                          Destroyed     No change
# 1                  No Visible Damage     No change
# 2                    Moderate Damage     No change
# 3                  No Visible Damage     No change
# 4                          Destroyed     No change
# ...                              ...           ...
# 7037  Impact Crater (Damage to Road)  New - damage
# 7038                 Moderate Damage  New - damage
# 7039  Impact Crater (Damage to Road)  New - damage
# 7040                 Moderate Damage  New - damage
# 7041                 Moderate Damage  New - damage
#
#                           GrDaCl                  FieldVl  \
# 0              Damaged Buildings  Not yet field validated
# 1              Damaged Buildings  Not yet field validated
# 2              Damaged Buildings  Not yet field validated
# 3              Damaged Buildings  Not yet field validated
# 4              Damaged Buildings  Not yet field validated
# ...                          ...                      ...
# 7037  Impacts on Roads / Bridges  Not yet field validated
# 7038       Damaged Road segments  Not yet field validated
# 7039  Impacts on Roads / Bridges  Not yet field validated
# 7040       Damaged Road segments  Not yet field validated
# 7041       Damaged Road segments  Not yet field validated
#
#                               Neigh           Code                   geometry
# 0     Al Jami Al Kabeer wa Al Wasat  CE20130604SYR  POINT (40.13379 35.34347)
# 1                            Qosour  CE20130604SYR  POINT (40.13147 35.34176)
# 2                            Qosour  CE20130604SYR  POINT (40.12980 35.34216)
# 3                            Qosour  CE20130604SYR  POINT (40.12923 35.34227)
# 4                           Shuhuda  CE20130604SYR  POINT (40.13174 35.33072)
# ...                             ...            ...                        ...
# 7037                       Maysalun  CE20130604SYR  POINT (40.14549 35.32312)
# 7038                       Maysalun  CE20130604SYR  POINT (40.14631 35.32267)
# 7039                        Shuhuda  CE20130604SYR  POINT (40.13676 35.32850)
# 7040                       Maysalun  CE20130604SYR  POINT (40.15772 35.31770)
# 7041              Tashreen Harabesh  CE20130604SYR  POINT (40.15949 35.31470)
#
# [7042 rows x 11 columns]

# %%
ax = geoplot.webmap(data_ezzor, projection=gcrs.WebMercator())
data_ezzor.plot(column='DaSitCl5',legend=True,ax=ax)
plt.show() #Marche pas ?

# %%
data_ezzor.plot(column='DaSitCl5',legend=True,figsize=(14,14))
plt.show()

# %%
latitude=[]
longitude=[]
for l in data_ezzor.geometry:
    latitude.append(l.x)
    longitude.append(l.x)

# %%
av_lat = sum(latitude) / len(latitude) 
av_long = sum(longitude) / len(longitude)

# %% [markdown]
# Pour monter notre premier modèle on va construire des labels 1=détruit et 0=non-détruit. Pour commencer je vais prendre tous les points 'détruits' peu importe si il s'agit d'un building, d'un cratère sur la route ou d'un cratère dans un champ.
# A discuter avec les garçons.

# %%
labels = data_ezzor['DaSitCl5'].astype('category').cat.categories.tolist()
labels
# Out:
# ['Destroyed',
#  'Impact Crater (Damage to Field)',
#  'Impact Crater (Damage to Road)',
#  'Moderate Damage',
#  'No Visible Damage',
#  'Severe Damage']

# %%
def coding(x):
    if x=='Destroyed':
        return 1
    if x=='Severe Damage':
        return 1
    if x=='Impact Crater (Damage to Field)':
        return 1
    if x=='Impact Crater (Damage to Road)':
        return 1
    if x=='Moderate Damage':
        return 0
    if x=='No Visible Damage':
        return 0
    else:
        return 0

# %%
data_ezzor['label']=data_ezzor['DaSitCl5'].apply(coding)

# %%
data_ezzor
# Out:
#                             SiteID     SensDt5      SensId5    ConfId5  \
# 0     Building (General / Default)  2017-11-09  Worldview-2     Medium
# 1     Building (General / Default)  2017-11-09  Worldview-2     Medium
# 2     Building (General / Default)  2017-11-09  Worldview-2  Uncertain
# 3     Building (General / Default)  2017-11-09  Worldview-2     Medium
# 4     Building (General / Default)  2017-11-09  Worldview-2  Very High
# ...                            ...         ...          ...        ...
# 7037                          Road  2017-11-09  Worldview-2  Very High
# 7038                          Road  2017-11-09  Worldview-2     Medium
# 7039                          Road  2017-11-09  Worldview-2  Very High
# 7040                          Road  2017-11-09  Worldview-2     Medium
# 7041                          Road  2017-11-09  Worldview-2     Medium
#
#                             DaSitCl5        Damst5  \
# 0                          Destroyed     No change
# 1                  No Visible Damage     No change
# 2                    Moderate Damage     No change
# 3                  No Visible Damage     No change
# 4                          Destroyed     No change
# ...                              ...           ...
# 7037  Impact Crater (Damage to Road)  New - damage
# 7038                 Moderate Damage  New - damage
# 7039  Impact Crater (Damage to Road)  New - damage
# 7040                 Moderate Damage  New - damage
# 7041                 Moderate Damage  New - damage
#
#                           GrDaCl                  FieldVl  \
# 0              Damaged Buildings  Not yet field validated
# 1              Damaged Buildings  Not yet field validated
# 2              Damaged Buildings  Not yet field validated
# 3              Damaged Buildings  Not yet field validated
# 4              Damaged Buildings  Not yet field validated
# ...                          ...                      ...
# 7037  Impacts on Roads / Bridges  Not yet field validated
# 7038       Damaged Road segments  Not yet field validated
# 7039  Impacts on Roads / Bridges  Not yet field validated
# 7040       Damaged Road segments  Not yet field validated
# 7041       Damaged Road segments  Not yet field validated
#
#                               Neigh           Code                   geometry  \
# 0     Al Jami Al Kabeer wa Al Wasat  CE20130604SYR  POINT (40.13379 35.34347)
# 1                            Qosour  CE20130604SYR  POINT (40.13147 35.34176)
# 2                            Qosour  CE20130604SYR  POINT (40.12980 35.34216)
# 3                            Qosour  CE20130604SYR  POINT (40.12923 35.34227)
# 4                           Shuhuda  CE20130604SYR  POINT (40.13174 35.33072)
# ...                             ...            ...                        ...
# 7037                       Maysalun  CE20130604SYR  POINT (40.14549 35.32312)
# 7038                       Maysalun  CE20130604SYR  POINT (40.14631 35.32267)
# 7039                        Shuhuda  CE20130604SYR  POINT (40.13676 35.32850)
# 7040                       Maysalun  CE20130604SYR  POINT (40.15772 35.31770)
# 7041              Tashreen Harabesh  CE20130604SYR  POINT (40.15949 35.31470)
#
#       label
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1
# ...     ...
# 7037      1
# 7038      0
# 7039      1
# 7040      0
# 7041      0
#
# [7042 rows x 12 columns]

# %%
data_ezzor.plot(column='label',legend=True,figsize=(14,14))
plt.show()

# %%
data_ezzor.label.mean() # A peu près moitié-moitié
# Out:
# 0.5583641011076399

# %%
print('{} observations positive, {} observations négatives'.format(len(data_ezzor[data_ezzor.label==1]),len(data_ezzor[data_ezzor.label==0])))
# Out:
# 3932 observations positive, 3110 observations négatives

# %%
data_label_ezzor=data_ezzor[['label','geometry']]

# %%
wd
# Out:
# 'C:\\Users\\morga\\Documents\\GitHub\\satellite_imagery'

# %%
data_label_ezzor.to_csv(wd+'\\data\\process\\data_label_ezzor.csv')

# %%
# Enlever le fichier temp à la fin ca entre pas dans le git :// !!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %% [markdown]
# ### La ville de Alep

# %%
from zipfile import ZipFile
zip = ZipFile(wd+'\\data\\UNITAR_data\\UNOSAT_CE20130604SYR_Syria_Damage_Assessment_2016_shp.zip')
zip.extractall('temp') # Enlever le fichier temp à la fin ca entre pas dans le git :// !!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
data_alep=gpd.read_file('temp\\6_Damage_Sites_Aleppo_SDA.shp')

# %% [markdown]
# On ne garde que les dernières observation qui datent de septembre 2016.

# %%
data_alep.columns
# Out:
# Index(['SiteID', 'SensDt', 'SensorID', 'ConfID', 'DmgCls', 'SensDt_2',
#        'SensID_2', 'ConfID_2', 'DmgCls_2', 'DmgSts_2', 'SensDt_3', 'SensID_3',
#        'ConfID_3', 'DmgCls_3', 'DmgSts_3', 'SensDt_4', 'SensID_4', 'ConfID_4',
#        'DmgCls_4', 'DmgSts_4', 'GrpDmgCls', 'FldValid', 'Notes', 'StlmtNme',
#        'Neighbrhd', 'EventCode', 'geometry'],
#       dtype='object')

# %%
data_alep=data_alep[['SiteID','SensDt_4','SensID_4','ConfID_4','DmgCls_4','DmgSts_4','GrpDmgCls','FldValid','Notes','StlmtNme','Neighbrhd','EventCode','geometry']]

# %%
data_alep.head()
# Out:
#                          SiteID    SensDt_4     SensID_4   ConfID_4  \
# 0  Building (General / Default)  2016-09-18  WorldView-3  Very High
# 1  Building (General / Default)  2016-09-18  WorldView-3  Very High
# 2  Building (General / Default)  2016-09-18  WorldView-3  Very High
# 3  Building (General / Default)  2016-09-18  WorldView-3  Very High
# 4  Building (General / Default)  2016-09-18  WorldView-3  Very High
#
#         DmgCls_4   DmgSts_4          GrpDmgCls                 FldValid Notes  \
# 0  Severe Damage  No change  Damaged Buildings  Not yet field validated  None
# 1  Severe Damage  No change  Damaged Buildings  Not yet field validated  None
# 2  Severe Damage  No change  Damaged Buildings  Not yet field validated  None
# 3  Severe Damage  No change  Damaged Buildings  Not yet field validated  None
# 4  Severe Damage  No change  Damaged Buildings  Not yet field validated  None
#
#   StlmtNme Neighbrhd      EventCode                   geometry
# 0   Aleppo   Rasafeh  CE20130604SYR  POINT (37.13543 36.23547)
# 1   Aleppo   Rasafeh  CE20130604SYR  POINT (37.13539 36.23557)
# 2   Aleppo   Rasafeh  CE20130604SYR  POINT (37.13908 36.24100)
# 3   Aleppo   Rasafeh  CE20130604SYR  POINT (37.13924 36.24098)
# 4   Aleppo   Rasafeh  CE20130604SYR  POINT (37.13939 36.24096)

# %%
ax = geoplot.webmap(data_alep, projection=gcrs.WebMercator())
data_alep.plot(column='DmgCls_4',legend=True,ax=ax)
plt.show() #Marche pas ?

# %%
data_alep.plot(column='DmgCls_4',legend=True,figsize=(14,14))
plt.show()

# %%
latitude=[]
longitude=[]
for l in data_alep.geometry:
    latitude.append(l.x)
    longitude.append(l.x)

# %%
av_lat = sum(latitude) / len(latitude) 
av_long = sum(longitude) / len(longitude)

# %% [markdown]
# Pour monter notre premier modèle on va construire des labels 1=détruit et 0=non-détruit. Pour commencer je vais prendre tous les points 'détruits' peu importe si il s'agit d'un building, d'un cratère sur la route ou d'un cratère dans un champ.
# A discuter avec les garçons.

# %%
labels = data_alep['DmgCls_4'].astype('category').cat.categories.tolist()
labels
# Out:
# ['Destroyed', 'Moderate Damage', 'No Visible Damage', 'Severe Damage']

# %%
def coding(x):
    if x=='Destroyed':
        return 1
    if x=='Severe Damage':
        return 1
    if x=='Moderate Damage':
        return 0
    if x=='No Visible Damage':
        return 0
    else:
        return 0

# %%
data_alep['label']=data_alep['DmgCls_4'].apply(coding)

# %%
data_alep
# Out:
#                              SiteID    SensDt_4     SensID_4   ConfID_4  \
# 0      Building (General / Default)  2016-09-18  WorldView-3  Very High
# 1      Building (General / Default)  2016-09-18  WorldView-3  Very High
# 2      Building (General / Default)  2016-09-18  WorldView-3  Very High
# 3      Building (General / Default)  2016-09-18  WorldView-3  Very High
# 4      Building (General / Default)  2016-09-18  WorldView-3  Very High
# ...                             ...         ...          ...        ...
# 35931  Building (General / Default)  2016-09-18  WorldView-3     Medium
# 35932  Building (General / Default)  2016-09-18  WorldView-3     Medium
# 35933  Building (General / Default)  2016-09-18  WorldView-3     Medium
# 35934  Building (General / Default)  2016-09-18  WorldView-3     Medium
# 35935  Building (General / Default)  2016-09-18  WorldView-3     Medium
#
#               DmgCls_4      DmgSts_4          GrpDmgCls  \
# 0        Severe Damage     No change  Damaged Buildings
# 1        Severe Damage     No change  Damaged Buildings
# 2        Severe Damage     No change  Damaged Buildings
# 3        Severe Damage     No change  Damaged Buildings
# 4        Severe Damage     No change  Damaged Buildings
# ...                ...           ...                ...
# 35931    Severe Damage  New - damage  Damaged Buildings
# 35932    Severe Damage  New - damage  Damaged Buildings
# 35933    Severe Damage  New - damage  Damaged Buildings
# 35934  Moderate Damage  New - damage  Damaged Buildings
# 35935    Severe Damage  New - damage  Damaged Buildings
#
#                       FldValid Notes StlmtNme Neighbrhd      EventCode  \
# 0      Not yet field validated  None   Aleppo   Rasafeh  CE20130604SYR
# 1      Not yet field validated  None   Aleppo   Rasafeh  CE20130604SYR
# 2      Not yet field validated  None   Aleppo   Rasafeh  CE20130604SYR
# 3      Not yet field validated  None   Aleppo   Rasafeh  CE20130604SYR
# 4      Not yet field validated  None   Aleppo   Rasafeh  CE20130604SYR
# ...                        ...   ...      ...       ...            ...
# 35931  Not yet field validated  None   Aleppo   Unknown  CE20130604SYR
# 35932  Not yet field validated  None   Aleppo   Unknown  CE20130604SYR
# 35933  Not yet field validated  None   Aleppo   Unknown  CE20130604SYR
# 35934  Not yet field validated  None   Aleppo   Unknown  CE20130604SYR
# 35935  Not yet field validated  None   Aleppo   Unknown  CE20130604SYR
#
#                         geometry  label
# 0      POINT (37.13543 36.23547)      1
# 1      POINT (37.13539 36.23557)      1
# 2      POINT (37.13908 36.24100)      1
# 3      POINT (37.13924 36.24098)      1
# 4      POINT (37.13939 36.24096)      1
# ...                          ...    ...
# 35931  POINT (37.21453 36.25966)      1
# 35932  POINT (37.21337 36.25920)      1
# 35933  POINT (37.21318 36.25930)      1
# 35934  POINT (37.21323 36.25940)      0
# 35935  POINT (37.21399 36.25914)      1
#
# [35936 rows x 14 columns]

# %%
data_alep.plot(column='label',legend=True,figsize=(14,14))
plt.show()

# %%
data_alep.label.mean() # A peu près moitié-moitié
# Out:
# 0.541323463935886

# %%
print('{} observations positive, {} observations négatives'.format(len(data_alep[data_alep.label==1]),len(data_alep[data_alep.label==0])))
# Out:
# 19453 observations positive, 16483 observations négatives

# %%
data_label_alep=data_alep[['label','geometry']]

# %%
wd
# Out:
# 'C:\\Users\\morga\\Documents\\GitHub\\satellite_imagery'

# %%
data_label_alep.to_csv(wd+'\\data\\process\\data_label_alep.csv')

# %%
# Enlever le fichier temp à la fin ca entre pas dans le git :// !!!!!!!!!!!!!!!!!!!!!!!!!!!!!
